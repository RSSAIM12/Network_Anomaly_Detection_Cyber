# %%
import pandas as pd
data = pd.read_csv("clean_data.csv")
print(data.head(1000))
data = pd.read_csv("dataset.csv")
print(data.head(1000))
# Out:
#               dur  proto  service  state     spkts     dpkts    sbytes  \
# 0    1.833334e-07    117       12      4  0.000094  0.000000  0.000033
# 1    1.333334e-07    117       12      4  0.000094  0.000000  0.000121
# 2    8.333335e-08    117       12      4  0.000094  0.000000  0.000073
# 3    1.000000e-07    117       12      4  0.000094  0.000000  0.000061
# 4    1.666667e-07    117       12      4  0.000094  0.000000  0.000146
# ..            ...    ...      ...    ...       ...       ...       ...
# 995  6.666668e-08    117       12      4  0.000094  0.000000  0.000010
# 996  1.407660e-02    111       12      3  0.001033  0.000726  0.000069
# 997  4.426434e-03    111        4      3  0.000845  0.000545  0.000060
# 998  1.409759e-02    111        4      3  0.000845  0.000726  0.000076
# 999  5.000001e-08    127       12      4  0.000094  0.000000  0.000011
#
#        dbytes      rate      sttl  ...  ct_dst_sport_ltm  ct_dst_src_ltm  \
# ...
